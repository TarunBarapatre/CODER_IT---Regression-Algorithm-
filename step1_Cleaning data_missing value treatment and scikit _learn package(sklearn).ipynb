# %%
import pandas as pd
import os

# %%
student_dateset= pd.read_excel('C:\\Users\\DELL\\Desktop\\Data Framing\\student_dataset.xls')

# %%
student_dateset
# Out:
#    gender   age  sleeping_time  study_time  mobile_time  sports_time
# 0       f  23.0            8.0         7.0          9.0          4.0
# 1       m  20.0            7.0         3.0          9.0          4.0
# 2       m  22.0           12.0         6.0          3.0          3.0
# 3       f  23.0            6.0         4.0          5.0          3.0
# 4     NaN  24.0           12.0         3.0          9.0          1.0
# 5       f  23.0            9.0         3.0          7.0          3.0
# 6       f   NaN            8.0         3.0          5.0          5.0
# 7       m  27.0            7.0         5.0          8.0          3.0
# 8       f  20.0            NaN         4.0          2.0          2.0
# 9       f  20.0            7.0         7.0          5.0          2.0
# 10      f  19.0            9.0         NaN          5.0          4.0
# 11      m  18.0            9.0         1.0          2.0          5.0
# 12      m  23.0            7.0         6.0          1.0          5.0
# ...

# %%
student_dateset
# Out:
#    gender   age  sleeping_time  study_time  mobile_time  sports_time
# 0       f  23.0            8.0         7.0          9.0          4.0
# 1       m  20.0            7.0         3.0          9.0          4.0
# 2       m  22.0           12.0         6.0          3.0          3.0
# 3       f  23.0            6.0         4.0          5.0          3.0
# 4     NaN  24.0           12.0         3.0          9.0          1.0
# 5       f  23.0            9.0         3.0          7.0          3.0
# 6       f   NaN            8.0         3.0          5.0          5.0
# 7       m  27.0            7.0         5.0          8.0          3.0
# 8       f  20.0            NaN         4.0          2.0          2.0
# 9       f  20.0            7.0         7.0          5.0          2.0
# 10      f  19.0            9.0         NaN          5.0          4.0
# 11      m  18.0            9.0         1.0          2.0          5.0
# 12      m  23.0            7.0         6.0          1.0          5.0
# ...

# %%
student_dateset.isnull().sum()
# Out:
# gender           4
# age              7
# sleeping_time    7
# study_time       7
# mobile_time      7
# sports_time      4
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(y='age',data=student_dateset)

# %%
sns.boxplot(y='study_time',data=student_dateset)

# %%
sns.boxplot(y='sports_time',data=student_dateset)

# %%
x = student_dateset.iloc[0:15,1:6].values

# %%
x
# Out:
# array([[23.,  8.,  7.,  9.,  4.],
#        [20.,  7.,  3.,  9.,  4.],
#        [22., 12.,  6.,  3.,  3.],
#        [23.,  6.,  4.,  5.,  3.],
#        [24., 12.,  3.,  9.,  1.],
#        [23.,  9.,  3.,  7.,  3.],
#        [nan,  8.,  3.,  5.,  5.],
#        [27.,  7.,  5.,  8.,  3.],
#        [20., nan,  4.,  2.,  2.],
#        [20.,  7.,  7.,  5.,  2.],
#        [19.,  9., nan,  5.,  4.],
#        [18.,  9.,  1.,  2.,  5.],
#        [23.,  7.,  6.,  1.,  5.],
#        [20.,  7.,  6., nan,  2.],
#        [22., 10.,  7.,  2.,  1.]])

# %%
pd.DataFrame(x)
# Out:
#        0     1    2    3    4
# 0   23.0   8.0  7.0  9.0  4.0
# 1   20.0   7.0  3.0  9.0  4.0
# 2   22.0  12.0  6.0  3.0  3.0
# 3   23.0   6.0  4.0  5.0  3.0
# 4   24.0  12.0  3.0  9.0  1.0
# 5   23.0   9.0  3.0  7.0  3.0
# 6    NaN   8.0  3.0  5.0  5.0
# 7   27.0   7.0  5.0  8.0  3.0
# 8   20.0   NaN  4.0  2.0  2.0
# 9   20.0   7.0  7.0  5.0  2.0
# 10  19.0   9.0  NaN  5.0  4.0
# 11  18.0   9.0  1.0  2.0  5.0
# 12  23.0   7.0  6.0  1.0  5.0
# 13  20.0   7.0  6.0  NaN  2.0
# 14  22.0  10.0  7.0  2.0  1.0

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values ='NaN', strategy ='mean', axis=0)
imputer = imputer.fit(x[:,1:6])
x[:,1:6] = imputer.transform(x[:,1:6])
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([[23.        ,  8.        ,  7.        ,  9.        ,  4.        ],
#        [20.        ,  7.        ,  3.        ,  9.        ,  4.        ],
#        [22.        , 12.        ,  6.        ,  3.        ,  3.        ],
#        [23.        ,  6.        ,  4.        ,  5.        ,  3.        ],
#        [24.        , 12.        ,  3.        ,  9.        ,  1.        ],
#        [23.        ,  9.        ,  3.        ,  7.        ,  3.        ],
#        [        nan,  8.        ,  3.        ,  5.        ,  5.        ],
#        [27.        ,  7.        ,  5.        ,  8.        ,  3.        ],
#        [20.        ,  8.42857143,  4.        ,  2.        ,  2.        ],
#        [20.        ,  7.        ,  7.        ,  5.        ,  2.        ],
#        [19.        ,  9.        ,  4.64285714,  5.        ,  4.        ],
#        [18.        ,  9.        ,  1.        ,  2.        ,  5.        ],
#        [23.        ,  7.        ,  6.        ,  1.        ,  5.        ],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values ='NaN', strategy ='median', axis=0)
imputer = imputer.fit(x[:,1:6])
x[:,1:6] = imputer.transform(x[:,1:6])
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([[23.        ,  8.        ,  7.        ,  9.        ,  4.        ],
#        [20.        ,  7.        ,  3.        ,  9.        ,  4.        ],
#        [22.        , 12.        ,  6.        ,  3.        ,  3.        ],
#        [23.        ,  6.        ,  4.        ,  5.        ,  3.        ],
#        [24.        , 12.        ,  3.        ,  9.        ,  1.        ],
#        [23.        ,  9.        ,  3.        ,  7.        ,  3.        ],
#        [        nan,  8.        ,  3.        ,  5.        ,  5.        ],
#        [27.        ,  7.        ,  5.        ,  8.        ,  3.        ],
#        [20.        ,  8.42857143,  4.        ,  2.        ,  2.        ],
#        [20.        ,  7.        ,  7.        ,  5.        ,  2.        ],
#        [19.        ,  9.        ,  4.64285714,  5.        ,  4.        ],
#        [18.        ,  9.        ,  1.        ,  2.        ,  5.        ],
#        [23.        ,  7.        ,  6.        ,  1.        ,  5.        ],
# ...

# %%
y = student_dateset.iloc[0:20,0:2].values

# %%
y
# Out:
# array([['f', 23.0],
#        ['m', 20.0],
#        ['m', 22.0],
#        ['f', 23.0],
#        [nan, 24.0],
#        ['f', 23.0],
#        ['f', nan],
#        ['m', 27.0],
#        ['f', 20.0],
#        ['f', 20.0],
#        ['f', 19.0],
#        ['m', 18.0],
#        ['m', 23.0],
#        ['f', 20.0],
#        ['m', 22.0],
#        ['f', 21.0],
#        ['f', 22.0],
#        ['m', 22.0],
#        ['m', 24.0],
#        ['f', 24.0]], dtype=object)

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy = 'most_frequent')
y[:,0:1] = imp.fit_transform(y[:,0:1])

# %%
y
# Out:
# array([['f', 23.0],
#        ['m', 20.0],
#        ['m', 22.0],
#        ['f', 23.0],
#        ['f', 24.0],
#        ['f', 23.0],
#        ['f', nan],
#        ['m', 27.0],
#        ['f', 20.0],
#        ['f', 20.0],
#        ['f', 19.0],
#        ['m', 18.0],
#        ['m', 23.0],
#        ['f', 20.0],
#        ['m', 22.0],
#        ['f', 21.0],
#        ['f', 22.0],
#        ['m', 22.0],
#        ['m', 24.0],
#        ['f', 24.0]], dtype=object)
